# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('C:\/items_first.json') as f:
  data = json.load(f)
data=data[0]

# %%
pp=[]
for i in range(0,len(data['product_price']),1):
    if(data['product_price'][i]!='.'):
        pp.append(data['product_price'][i])  
print(len(pp))
# Out:
# 16

# %%
count=0
left=[]
names=[]
price=[]
ratings=[]
for i in range(0,len(data['product_name'])):
    count+=1
    left.append(count)
    names.append(data['product_name'][i])
    price.append(pp[i])
    ls=data['product_review'][i].split()
    ratings.append(ls[0])
ratings_price=[]
for i in range(0,len(price),1):
    ratings_price.append(round((float(price[i])/float(ratings[i])),3))

# %%
print(len(left))
print(names)
print(len(price))
print(ratings)
print(ratings_price)
# Out:
# 16
# ['What Happened to You?: Conversations on Trauma, Resilience, and Healing', 'World Travel: An Irreverent Guide', "Out of Many, One: Portraits of America's Immigrants", 'Sooley: A Novel', 'Cook This Book: Techniques That Teach and Recipes to Repeat: A Cookbook', 'On the House: A Washington Memoir', "Fault Lines: The Social Justice Movement and Evangelicalism's Looming Catastrophe", 'Woman Evolve: Break Up with Your Fears and Revolutionize Your Life', 'The Crown of Gilded Bones (Blood And Ash Series Book 3)', "Don't Drop the Mic: The Power of Your Words Can Change the World", 'Vegetable Simple: A Cookbook', "F*ck It, I'll Start Tomorrow", 'Philip Roth: The Biography', 'The Hero Code: Lessons Learned from Lives Well Lived', 'A Gambling Man (An Archer Novel Book 2)', 'You Are Your Best Thing: Vulnerability, Shame Resilience, and the Black Experience']
# 16
# ['3.9', '4.2', '4.7', '4.6', '4.8', '4.3', '4.9', '5.0', '4.7', '4.9', '3.8', '4.9', '4.4', '4.7', '4.5', '5.0']
# [4.359, 5.0, 4.681, 3.043, 3.958, 3.953, 3.265, 2.8, 1.277, 3.061, 5.526, 3.061, 5.455, 2.766, 3.111, 3.2]

# %%
x=np.array(left)
y=np.array(ratings_price)
plt.xticks(np.arange(0, len(names)+1, 1),fontsize=20)
plt.yticks(np.arange(0, len(ratings_price)+1, 0.5),fontsize=18)
plt.bar(x,y)
plt.rcParams["figure.figsize"] = (50,5)
plt.ylim(ymin=0) 
plt.show()
for i in range(0,len(left),1):
    print(left[i],"\t",names[i],"\t",ratings_price[i])
# Out:
# 1 	 What Happened to You?: Conversations on Trauma, Resilience, and Healing 	 4.359
# 2 	 World Travel: An Irreverent Guide 	 5.0
# 3 	 Out of Many, One: Portraits of America's Immigrants 	 4.681
# 4 	 Sooley: A Novel 	 3.043
# 5 	 Cook This Book: Techniques That Teach and Recipes to Repeat: A Cookbook 	 3.958
# 6 	 On the House: A Washington Memoir 	 3.953
# 7 	 Fault Lines: The Social Justice Movement and Evangelicalism's Looming Catastrophe 	 3.265
# 8 	 Woman Evolve: Break Up with Your Fears and Revolutionize Your Life 	 2.8
# 9 	 The Crown of Gilded Bones (Blood And Ash Series Book 3) 	 1.277
# 10 	 Don't Drop the Mic: The Power of Your Words Can Change the World 	 3.061
# 11 	 Vegetable Simple: A Cookbook 	 5.526
# 12 	 F*ck It, I'll Start Tomorrow 	 3.061
# 13 	 Philip Roth: The Biography 	 5.455
# 14 	 The Hero Code: Lessons Learned from Lives Well Lived 	 2.766
# 15 	 A Gambling Man (An Archer Novel Book 2) 	 3.111
# 16 	 You Are Your Best Thing: Vulnerability, Shame Resilience, and the Black Experience 	 3.2
